# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score
)

# %%
X_test = joblib.load("../models/data/X_test.pkl")
y_test = joblib.load("../models/data/y_test.pkl")

model = joblib.load("../models/RandomForest.pkl")

print("Model and test data loaded")
# Out:
# Model and test data loaded

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("\nAccuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9625
# Precision: 0.9503164556962026
# Recall: 0.9625
# F1 Score: 0.9563694267515924

# %%
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       234
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.96       240
#    macro avg       0.49      0.49      0.49       240
# weighted avg       0.95      0.96      0.96       240

# %%
cm = confusion_matrix(y_test, y_pred)

print("\nConfusion Matrix:\n")
print(cm)
# Out:
# Confusion Matrix:
#
# [[231   3]
#  [  6   0]]

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()
